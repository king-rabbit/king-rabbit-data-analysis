# %% [markdown]
# 넷플릭스 콘텐츠 분석하기
# =================
#
# > 넷플릭스 영화 및 TV 콘텐츠를 분석해 본 내용입니다. 데이터는 kaggle의 데이터셋을 이용했습니다.
# > 데이터와 분석 노트북은 깃허브 리포지토리에서 확인하실 수 있습니다.
# > + [데이터셋 바로가기][link]
# > + [리포지토리 바로가기][link_repository]
#
# [link]: https://www.kaggle.com/shivamb/netflix-shows "netflix-shows-dataset"
# [link_repository]: https://github.com/king-rabbit

# %% [markdown]
# 1. 데이터 불러오기
# > 필요한 라이브러리와 데이터를 불러오고 데이터 형식 등을 확인해봅니다.

# %%
import warnings
import pandas as pd
import numpy as np
from pyecharts import Bar, Line, Pie, Map
warnings.filterwarnings(action='ignore')

# %%
data = pd.read_csv('netflix_titles.csv')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8807 entries, 0 to 8806
# Data columns (total 12 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   show_id       8807 non-null   object
#  1   type          8807 non-null   object
#  2   title         8807 non-null   object
#  3   director      6173 non-null   object
#  4   cast          7982 non-null   object
#  5   country       7976 non-null   object
#  6   date_added    8797 non-null   object
#  7   release_year  8807 non-null   int64
#  8   rating        8803 non-null   object
#  9   duration      8804 non-null   object
#  10  listed_in     8807 non-null   object
#  11  description   8807 non-null   object
# dtypes: int64(1), object(11)
# memory usage: 825.8+ KB

# %%
data.head(5)
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# 2  September 24, 2021          2021  TV-MA   1 Season
# 3  September 24, 2021          2021  TV-MA   1 Season
# 4  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                            listed_in  \
# 0                                      Documentaries
# 1    International TV Shows, TV Dramas, TV Mysteries
# 2  Crime TV Shows, International TV Shows, TV Act...
# 3                             Docuseries, Reality TV
# 4  International TV Shows, Romantic TV Shows, TV ...
#
#                                          description
# 0  As her father nears the end of his life, filmm...
# 1  After crossing paths at a party, a Cape Town t...
# 2  To protect his family from a powerful drug lor...
# 3  Feuds, flirtations and toilet talk go down amo...
# 4  In a city of coaching centers known to train I...

# %%
for i in range(len(data)):
    try:
        data.loc[i, 'country'] = data.loc[i, 'country'].replace("\"", "")
    except:
        pass

# %%
countries = []
for i in range(len(data)):
    if type(data.loc[i, 'country']) == str:
        countries_content = data.loc[i, 'country'].split(', ')
        for country in countries_content:
            countries.append(country)
    else:
        pass

countries = list(set(countries))

# %%
#countries.remove('')
countires_re = [ country.replace(',', '') for country in countries ]

# %%
countires_re = list(set(countires_re))

# %%
countries_cnt = []
for country in countires_re:
    cnt = 0
    for i in range(len(data)):
        if type(data.loc[i, 'country']) == str and data.loc[i, 'country'].__contains__(country):
            cnt +=1
    countries_cnt.append(cnt)

# %%
countries_movie_number = pd.DataFrame({'country':countires_re, 'count':countries_cnt})
countries_movie_number.to_csv('국가별_콘텐츠_개수.csv')

# %%
countries_movie_number = pd.read_csv('국가별_콘텐츠_개수.csv')

# %%
wmap = Map("", width=1000, height=600)
wmap.add(
    "",
    list(countries_movie_number['country'].values),
    list(countries_movie_number['count'].values),
    maptype="world",
    is_visualmap=True,
    visual_text_color="#000",
)
wmap
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="237000f5e3d64d3eb34d9fa653a05275" style="width:1000px;height:600px;"></div>
#
#
# <script>
#     require(['echarts', 'world'], function(echarts) {
#
# var myChart_237000f5e3d64d3eb34d9fa653a05275 = echarts.init(document.getElementById('237000f5e3d64d3eb34d9fa653a05275'), 'light', {renderer: 'canvas'});
#
# var option_237000f5e3d64d3eb34d9fa653a05275 = {
#     "title": [
#         {
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "save as image"
#             },
#             "restore": {
#                 "show": true,
#                 "title": "restore"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "data view"
#             }
#         }
#     },
#     "series_id": 89442,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "map",
#             "symbol": "circle",
#             "label": {
#                 "normal": {
#                     "show": false,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "mapType": "world",
#             "data": [
#                 {
#                     "name": NaN,
#                     "value": 7976.0
#                 },
#                 {
#                     "name": "Lithuania",
#                     "value": 1.0
#                 },
#                 {
#                     "name": "Nepal",
#                     "value": 2.0
#                 },
#                 {
#                     "name": "Iraq",
#                     "value": 2.0
#                 },
#                 {
#                     "name": "Paraguay",
#                     "value": 1.0
#                 },
#                 {
#                     "name": "Kuwait",
#                     "value": 8.0
#                 },
#                 {
#                     "name": "Argentina",
#                     "value": 91.0
#                 },
#                 {
#                     "name": "East Germany",
#                     "value": 1.0
#                 },
#                 {
#                     "name": "China",
#                     "value": 162.0
#                 },
#                 {
#                     "name": "Bangladesh",
#                     "value": 4.0
#                 },
#                 {
#                     "name": "United Arab Emirates",
#                     "value": 37.0
#                 },
#                 {
#                     "name": "Malawi",
#                     "value": 1.0
#                 },
#                 {
#                     "name": "Vatican City",
#                     "value": 1.0
#                 },
#                 {
#                     "name": "Georgia",
#                     "value": 2.0
#                 },
#                 {
#                     "name": "Mozambique",
#                     "value": 1.0
#                 },
#                 {
#                     "name": "Russia",
#                     "value": 27.0
#                 },
#                 {
#                     "name": "Sweden",
#                     "value": 42.0
#                 },
#                 {
#                     "name": "Nigeria",
#                     "value": 103.0
#                 },
#                 {
#                     "name": "South Korea",
#                     "value": 231.0
#                 },
#                 {
#                     "name": "Kenya",
#                     "value": 6.0
#                 },
#                 {
#                     "name": "Jamaica",
#                     "value": 1.0
#                 },
#                 {
#                     "name": "Kazakhstan",
#                     "value": 1.0
#                 },
#                 {
#                     "name": "Norway",
#                     "value": 30.0
#                 },
#                 {
#                     "name": "Bulgaria",
#                     "value": 10.0
#                 },
#                 {
#                     "name": "Germany",
#                     "value": 231.0
#                 },
#                 {
#                     "name": "Brazil",
#                     "value": 97.0
#                 },
#                 {
#                     "name": "Israel",
#                     "value": 30.0
#                 },
#                 {
#                     "name": "Portugal",
#                     "value": 6.0
#                 },
#                 {
#                     "name": "Somalia",
#                     "value": 1.0
#                 },
#                 {
#                     "name": "United Kingdom",
#                     "value": 806.0
#                 },
#                 {
#                     "name": "Cameroon",
#                     "value": 1.0
#                 },
#                 {
#                     "name": "Puerto Rico",
#                     "value": 1.0
#                 },
#                 {
#                     "name": "Dominican Republic",
#                     "value": 1.0
#                 },
#                 {
#                     "name": "Iceland",
#                     "value": 11.0
#                 },
#                 {
#                     "name": "Samoa",
#                     "value": 1.0
#                 },
#                 {
#                     "name": "Senegal",
#                     "value": 3.0
#                 },
#                 {
#                     "name": "Thailand",
#                     "value": 70.0
#                 },
#                 {
#                     "name": "Lebanon",
#                     "value": 31.0
#                 },
#                 {
#                     "name": "Uruguay",
#                     "value": 14.0
#                 },
#                 {
#                     "name": "Bahamas",
#                     "value": 1.0
#                 },
#                 {
#                     "name": "South Africa",
#                     "value": 62.0
#                 },
#                 {
#                     "name": "Spain",
#                     "value": 232.0
#                 },
#                 {
#                     "name": "West Germany",
#                     "value": 5.0
#                 },
#                 {
#                     "name": "Ethiopia",
#                     "value": 1.0
#                 },
#                 {
#                     "name": "Mexico",
#                     "value": 169.0
#                 },
#                 {
#                     "name": "New Zealand",
#                     "value": 33.0
#                 },
#                 {
#                     "name": "Cuba",
#                     "value": 1.0
#                 },
#                 {
#                     "name": "Sudan",
#                     "value": 1.0
#                 },
#                 {
#                     "name": "Austria",
#                     "value": 12.0
#                 },
#                 {
#                     "name": "Japan",
#                     "value": 318.0
#                 },
#                 {
#                     "name": "Hungary",
#                     "value": 11.0
#                 },
#                 {
#                     "name": "Jordan",
#                     "value": 9.0
#                 },
#                 {
#                     "name": "India",
#                     "value": 1046.0
#                 }

# %%
countries_movie_number.sort_values(by='count', ascending=False)[:10]
# Out:
#      Unnamed: 0         country  count
# 0             0             NaN   7976
# 102         102   United States   3690
# 52           52           India   1046
# 29           29  United Kingdom    806
# 79           79          Canada    445
# 53           53          France    393
# 49           49           Japan    318
# 41           41           Spain    232
# 24           24         Germany    231
# 18           18     South Korea    231

# %%
contents_by_year = pd.DataFrame(data['release_year'].value_counts()).reset_index().rename(columns={'index':'year', 'release_year':'count'}).sort_values(by='year')

# %%
bar = Bar("",
         width=1200)
bar.use_theme("dark")
bar.add("release_year", 
        contents_by_year['year'], 
        contents_by_year['count'],
        xaxis_label_textsize =9,
        label_text_size=10,
        is_label_show=True, 
        is_stack=True,
        is_datazoom_show=False)
bar
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="e49c130ef9a14e7f9c8c7e0cebe419de" style="width:1200px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_e49c130ef9a14e7f9c8c7e0cebe419de = echarts.init(document.getElementById('e49c130ef9a14e7f9c8c7e0cebe419de'), 'dark', {renderer: 'canvas'});
#
# var option_e49c130ef9a14e7f9c8c7e0cebe419de = {
#     "title": [
#         {
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "save as image"
#             },
#             "restore": {
#                 "show": true,
#                 "title": "restore"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "data view"
#             }
#         }
#     },
#     "series_id": 2780586,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "bar",
#             "name": "release_year",
#             "data": [
#                 1.0,
#                 2.0,
#                 3.0,
#                 3.0,
#                 4.0,
#                 2.0,
#                 1.0,
#                 2.0,
#                 3.0,
#                 2.0,
#                 3.0,
#                 1.0,
#                 4.0,
#                 1.0,
#                 3.0,
#                 2.0,
#                 2.0,
#                 2.0,
#                 1.0,
#                 5.0,
#                 3.0,
#                 2.0,
#                 2.0,
#                 5.0,
#                 5.0,
#                 10.0,
#                 7.0,
#                 7.0,
#                 9.0,
#                 7.0,
#                 7.0,
#                 11.0,
#                 11.0,
#                 13.0,
#                 17.0,
#                 11.0,
#                 12.0,
#                 10.0,
#                 13.0,
#                 8.0,
#                 18.0,
#                 16.0,
#                 22.0,
#                 17.0,
#                 23.0,
#                 28.0,
#                 22.0,
#                 25.0,
#                 24.0,
#                 38.0,
#                 36.0,
#                 39.0,
#                 37.0,
#                 45.0,
#                 51.0,
#                 61.0,
#                 64.0,
#                 80.0,
#                 96.0,
#                 88.0,
#                 136.0,
#                 152.0,
#                 194.0,
#                 185.0,
#                 237.0,
#                 288.0,
#                 352.0,
#                 560.0,
#                 902.0,
#                 1032.0,
#                 1147.0,
#                 1030.0,
#                 953.0,
#                 592.0
#             ],
#             "stack": "stack_2780586",
#             "barCategoryGap": "20%",
#             "label": {
#                 "normal": {
#                     "show": true,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 10
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "markLine": {
#                 "data": []
#             },
#             "seriesId": 2780586
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "release_year"
#             ],
#             "selectedMode": "multiple",
#             "show": true,
#             "left": "center",
#             "top": "top",
#             "orient": "horizontal",
#             "textStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "animation": true,
#     "xAxis": [
#         {
#             "show": true,
#             "nameLocation": "middle",
#             "nameGap": 25,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "boundaryGap": true,
#             "type": "category",
#             "splitLine": {
#                 "show": false
#             },
#             "axisLine": {
#                 "lineStyle": {
#                     "width": 1
#                 }
#             },
#             "axisLabel": {
#                 "interval": "auto",
#                 "rotate": 0,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 9
#                 }
#             },
#             "data": [
#                 1925.0,
#                 1942.0,
#                 1943.0,
#                 1944.0,
#                 1945.0,
#                 1946.0,
#                 1947.0,
#                 1954.0,
#                 1955.0,
#                 1956.0,
#                 1958.0,
#                 1959.0,
#                 1960.0,
#                 1961.0,
#                 1962.0,
#                 1963.0,
#                 1964.0,
#                 1965.0,
#                 1966.0,
#                 1967.0,
#                 1968.0,
#                 1969.0,
#                 1970.0,
#                 1971.0,
#                 1972.0,
#                 1973.0,
#                 1974.0,
#                 1975.0,
#                 1976.0,
#                 1977.0,
#                 1978.0,
#                 1979.0,
#                 1980.0,
#                 1981.0,
#                 1982.0,
#                 1983.0,
#                 1984.0,
#                 1985.0,
#                 1986.0,
#                 1987.0,
#                 1988.0,
#                 1989.0,
#                 1990.0,
#                 1991.0,
#                 1992.0,
#                 1993.0,
#                 1994.0,
#                 1995.0,
#                 1996.0,
#                 1997.0,
#                 1998.0,
#                 1999.0,
#                 2000.0,
#                 2001.0,
#                 2002.0,
#                 2003.0,
#                 2004.0,
#                 2005.0,
#                 2006.0,
#                 2007.0,
#                 2008.0,
#                 2009.0,
#                 2010.0,
#                 2011.0,
#                 2012.0,
#                 2013.0,
#                 2014.0,
#                 2015.0,
#                 2016.0,
#                 2017.0,
#                 2018.0,
#                 2019.0,
#                 2020.0,
#                 2021.0
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "nameLocation": "middle",
#             "nameGap": 25,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "boundaryGap": true,
#             "type": "value",
#             "splitLine": {
#                 "show": true
#             },
#             "axisLine": {
#                 "lineStyle": {
#                     "width": 1
#                 }
#             },
#             "axisLabel": {
#                 "interval": "auto",
#                 "formatter": "{value} ",
#                 "rotate": 0,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 12
#                 }
#             }
#         }
#     ],
#     "color": []
# };
# myChart_e49c130ef9a14e7f9c8c7e0cebe419de.setOption(option_e49c130ef9a14e7f9c8c7e0cebe419de);
#
#     });
# </script>

# %%
for i in range(len(data)):
    if type(data.loc[i, 'date_added']) == str:
        data.loc[i, 'date_added_year'] = data.loc[i, 'date_added'][-4:]

# %%
contents_added_year = pd.DataFrame(data['date_added_year'].value_counts()).reset_index().rename(columns={'index':'year', 'date_added_year':'count'}).sort_values(by='year')

# %%
bar = Bar("",
         width=1200)
bar.use_theme("dark")
bar.add("data_added_year", 
        contents_added_year['year'], 
        contents_added_year['count'],
        xaxis_label_textsize =9,
        label_text_size=10,
        is_label_show=True, 
        is_stack=True,
        is_datazoom_show=False)
bar
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="31aa32180e764c2ba420d18d76ddfbc4" style="width:1200px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_31aa32180e764c2ba420d18d76ddfbc4 = echarts.init(document.getElementById('31aa32180e764c2ba420d18d76ddfbc4'), 'dark', {renderer: 'canvas'});
#
# var option_31aa32180e764c2ba420d18d76ddfbc4 = {
#     "title": [
#         {
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "save as image"
#             },
#             "restore": {
#                 "show": true,
#                 "title": "restore"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "data view"
#             }
#         }
#     },
#     "series_id": 5497240,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "bar",
#             "name": "data_added_year",
#             "data": [
#                 2.0,
#                 2.0,
#                 1.0,
#                 13.0,
#                 3.0,
#                 11.0,
#                 24.0,
#                 82.0,
#                 429.0,
#                 1188.0,
#                 1649.0,
#                 2016.0,
#                 1879.0,
#                 1498.0
#             ],
#             "stack": "stack_5497240",
#             "barCategoryGap": "20%",
#             "label": {
#                 "normal": {
#                     "show": true,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 10
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "markLine": {
#                 "data": []
#             },
#             "seriesId": 5497240
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "data_added_year"
#             ],
#             "selectedMode": "multiple",
#             "show": true,
#             "left": "center",
#             "top": "top",
#             "orient": "horizontal",
#             "textStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "animation": true,
#     "xAxis": [
#         {
#             "show": true,
#             "nameLocation": "middle",
#             "nameGap": 25,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "boundaryGap": true,
#             "type": "category",
#             "splitLine": {
#                 "show": false
#             },
#             "axisLine": {
#                 "lineStyle": {
#                     "width": 1
#                 }
#             },
#             "axisLabel": {
#                 "interval": "auto",
#                 "rotate": 0,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 9
#                 }
#             },
#             "data": [
#                 2008.0,
#                 2009.0,
#                 2010.0,
#                 2011.0,
#                 2012.0,
#                 2013.0,
#                 2014.0,
#                 2015.0,
#                 2016.0,
#                 2017.0,
#                 2018.0,
#                 2019.0,
#                 2020.0,
#                 2021.0
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "nameLocation": "middle",
#             "nameGap": 25,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "boundaryGap": true,
#             "type": "value",
#             "splitLine": {
#                 "show": true
#             },
#             "axisLine": {
#                 "lineStyle": {
#                     "width": 1
#                 }
#             },
#             "axisLabel": {
#                 "interval": "auto",
#                 "formatter": "{value} ",
#                 "rotate": 0,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 12
#                 }
#             }
#         }
#     ],
#     "color": []
# };
# myChart_31aa32180e764c2ba420d18d76ddfbc4.setOption(option_31aa32180e764c2ba420d18d76ddfbc4);
#
#     });
# </script>

# %%
for i in range(len(data)):
    if data.loc[i, 'release_year'] <= 1980:
        data.loc[i, 'before_1980'] = 1
    else:
        data.loc[i, 'before_1980'] = 0

# %%
pd.pivot_table(data,  index=['date_added_year'], columns=['before_1980'],  aggfunc='count')['title']
# Out:
# before_1980         0.0   1.0
# date_added_year
# 2008                2.0   NaN
# 2009                2.0   NaN
# 2010                1.0   NaN
# 2011               13.0   NaN
# 2012                3.0   NaN
# 2013               11.0   NaN
# 2014               24.0   NaN
# 2015               82.0   NaN
# 2016              427.0   2.0
# 2017             1158.0  30.0
# 2018             1635.0  14.0
# 2019             1967.0  49.0
# 2020             1855.0  24.0
# 2021             1484.0  14.0

# %%
# 카테고리 분석

# %%
data.head(5)
# Out:
#   show_id     type                  title         director  \
# 0      s1    Movie   Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show          Blood & Water              NaN
# 2      s3  TV Show              Ganglands  Julien Leclercq
# 3      s4  TV Show  Jailbirds New Orleans              NaN
# 4      s5  TV Show           Kota Factory              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
# 2  Sami Bouajila, Tracy Gotoas, Samuel Jouy, Nabi...            NaN
# 3                                                NaN            NaN
# 4  Mayur More, Jitendra Kumar, Ranjan Raj, Alam K...          India
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
# 2  September 24, 2021          2021  TV-MA   1 Season
# 3  September 24, 2021          2021  TV-MA   1 Season
# 4  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                            listed_in  \
# 0                                      Documentaries
# 1    International TV Shows, TV Dramas, TV Mysteries
# 2  Crime TV Shows, International TV Shows, TV Act...
# 3                             Docuseries, Reality TV
# 4  International TV Shows, Romantic TV Shows, TV ...
#
#                                          description
# 0  As her father nears the end of his life, filmm...
# 1  After crossing paths at a party, a Cape Town t...
# 2  To protect his family from a powerful drug lor...
# 3  Feuds, flirtations and toilet talk go down amo...
# 4  In a city of coaching centers known to train I...

# %%
categories = []

for i in range(len(data)):
    cats = data.loc[i, 'listed_in'].split(', ')
    for cat in cats:
        categories.append(cat)

categories = set(categories)

# %%
show_ids = []
categories_list = []

for i in range(len(data)):
    cats = data.loc[i, 'listed_in'].split(', ')
    for cat in cats:
        show_ids.append(data.loc[i, 'show_id'])
        categories_list.append(cat)

# %%
show_category = pd.DataFrame({'show_id':show_ids, 'category':categories_list})

# %%
bar = Bar("",
         width=1200)
bar.use_theme("dark")
bar.add("category", 
        show_category.category.value_counts()[:10].keys(), 
        show_category.category.value_counts()[:10].values,
        xaxis_type ='category',
        xaxis_label_textsize =9,
        xaxis_interval =0,
        label_text_size=10,
        is_label_show=True, 
        is_datazoom_show=False)
bar
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="cf0c5cf5835f495eac7b1854735aed8d" style="width:1200px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_cf0c5cf5835f495eac7b1854735aed8d = echarts.init(document.getElementById('cf0c5cf5835f495eac7b1854735aed8d'), 'dark', {renderer: 'canvas'});
#
# var option_cf0c5cf5835f495eac7b1854735aed8d = {
#     "title": [
#         {
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "save as image"
#             },
#             "restore": {
#                 "show": true,
#                 "title": "restore"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "data view"
#             }
#         }
#     },
#     "series_id": 8282493,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "bar",
#             "name": "category",
#             "data": [
#                 2752.0,
#                 2427.0,
#                 1674.0,
#                 1351.0,
#                 869.0,
#                 859.0,
#                 763.0,
#                 756.0,
#                 641.0,
#                 616.0
#             ],
#             "barCategoryGap": "20%",
#             "label": {
#                 "normal": {
#                     "show": true,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 10
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "markLine": {
#                 "data": []
#             },
#             "seriesId": 8282493
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "category"
#             ],
#             "selectedMode": "multiple",
#             "show": true,
#             "left": "center",
#             "top": "top",
#             "orient": "horizontal",
#             "textStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "animation": true,
#     "xAxis": [
#         {
#             "show": true,
#             "nameLocation": "middle",
#             "nameGap": 25,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "boundaryGap": true,
#             "type": "category",
#             "splitLine": {
#                 "show": false
#             },
#             "axisLine": {
#                 "lineStyle": {
#                     "width": 1
#                 }
#             },
#             "axisLabel": {
#                 "interval": 0,
#                 "rotate": 0,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 9
#                 }
#             },
#             "data": [
#                 "International Movies",
#                 "Dramas",
#                 "Comedies",
#                 "International TV Shows",
#                 "Documentaries",
#                 "Action & Adventure",
#                 "TV Dramas",
#                 "Independent Movies",
#                 "Children & Family Movies",
#                 "Romantic Movies"
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "nameLocation": "middle",
#             "nameGap": 25,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "boundaryGap": true,
#             "type": "value",
#             "splitLine": {
#                 "show": true
#             },
#             "axisLine": {
#                 "lineStyle": {
#                     "width": 1
#                 }
#             },
#             "axisLabel": {
#                 "interval": "auto",
#                 "formatter": "{value} ",
#                 "rotate": 0,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 12
#                 }
#             }
#         }
#     ],
#     "color": []
# };
# myChart_cf0c5cf5835f495eac7b1854735aed8d.setOption(option_cf0c5cf5835f495eac7b1854735aed8d);
#
#     });
# </script>

# %%
pie = Pie("")
pie.add("", data['type'].value_counts().index, data['type'].value_counts().values, is_label_show=True)
pie
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="6593a101d55147bc9817b0bc43742a61" style="width:800px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_6593a101d55147bc9817b0bc43742a61 = echarts.init(document.getElementById('6593a101d55147bc9817b0bc43742a61'), 'light', {renderer: 'canvas'});
#
# var option_6593a101d55147bc9817b0bc43742a61 = {
#     "title": [
#         {
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "save as image"
#             },
#             "restore": {
#                 "show": true,
#                 "title": "restore"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "data view"
#             }
#         }
#     },
#     "series_id": 2060866,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "pie",
#             "data": [
#                 {
#                     "name": "Movie",
#                     "value": 6131.0
#                 },
#                 {
#                     "name": "TV Show",
#                     "value": 2676.0
#                 }
#             ],
#             "radius": [
#                 "0%",
#                 "75%"
#             ],
#             "center": [
#                 "50%",
#                 "50%"
#             ],
#             "label": {
#                 "normal": {
#                     "show": true,
#                     "position": "outside",
#                     "textStyle": {
#                         "fontSize": 12
#                     },
#                     "formatter": "{b}: {d}%"
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     },
#                     "formatter": "{b}: {d}%"
#                 }
#             },
#             "seriesId": 2060866
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "Movie",
#                 "TV Show"
#             ],
#             "selectedMode": "multiple",
#             "show": true,
#             "left": "center",
#             "top": "top",
#             "orient": "horizontal",
#             "textStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "animation": true,
#     "color": [
#         "#c23531",
#         "#2f4554",
#         "#61a0a8",
#         "#d48265",
#         "#749f83",
#         "#ca8622",
#         "#bda29a",
#         "#6e7074",
#         "#546570",
#         "#c4ccd3",
#         "#f05b72",
#         "#ef5b9c",
#         "#f47920",
#         "#905a3d",
#         "#fab27b",
#         "#2a5caa",
#         "#444693",
#         "#726930",
#         "#b2d235",
#         "#6d8346",
#         "#ac6767",
#         "#1d953f",
#         "#6950a1",
#         "#918597",
#         "#f6f5ec"
#     ]
# };
# myChart_6593a101d55147bc9817b0bc43742a61.setOption(option_6593a101d55147bc9817b0bc43742a61);
#
#     });
# </script>

# %%
data.head(2)
# Out:
#   show_id     type                 title         director  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show         Blood & Water              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                          listed_in  \
# 0                                    Documentaries
# 1  International TV Shows, TV Dramas, TV Mysteries
#
#                                          description date_added_year
# 0  As her father nears the end of his life, filmm...            2021
# 1  After crossing paths at a party, a Cape Town t...            2021

# %%
added_type_cnt = data.pivot_table(index='date_added_year', columns='type', values='title', aggfunc='count').reset_index()

# %%
bar = Bar("",
         width=1200)
bar.use_theme("dark")
bar.add("", 
        added_type_cnt.date_added_year, 
        added_type_cnt.Movie,
        xaxis_label_textsize =9,
        xaxis_interval =0,
        label_text_size=10,
        is_stack=True,
        is_label_show=False, 
        is_datazoom_show=False)

bar.add("", 
        added_type_cnt.date_added_year, 
        added_type_cnt['TV Show'],
        xaxis_label_textsize =9,
        xaxis_interval =0,
        label_text_size=10,
        is_stack=True,
        is_label_show=False, 
        is_datazoom_show=False)
bar
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="480d7f8395cc4feeb7804781967ce448" style="width:1200px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_480d7f8395cc4feeb7804781967ce448 = echarts.init(document.getElementById('480d7f8395cc4feeb7804781967ce448'), 'dark', {renderer: 'canvas'});
#
# var option_480d7f8395cc4feeb7804781967ce448 = {
#     "title": [
#         {
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "save as image"
#             },
#             "restore": {
#                 "show": true,
#                 "title": "restore"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "data view"
#             }
#         }
#     },
#     "series_id": 5181155,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "bar",
#             "data": [
#                 1.0,
#                 2.0,
#                 1.0,
#                 13.0,
#                 3.0,
#                 6.0,
#                 19.0,
#                 56.0,
#                 253.0,
#                 839.0,
#                 1237.0,
#                 1424.0,
#                 1284.0,
#                 993.0
#             ],
#             "stack": "stack_5181155",
#             "barCategoryGap": "20%",
#             "label": {
#                 "normal": {
#                     "show": false,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 10
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "markLine": {
#                 "data": []
#             },
#             "seriesId": 5181155
#         },
#         {
#             "type": "bar",
#             "data": [
#                 1.0,
#                 NaN,
#                 NaN,
#                 NaN,
#                 NaN,
#                 5.0,
#                 5.0,
#                 26.0,
#                 176.0,
#                 349.0,
#                 412.0,
#                 592.0,
#                 595.0,
#                 505.0
#             ],
#             "stack": "stack_5181155",
#             "barCategoryGap": "20%",
#             "label": {
#                 "normal": {
#                     "show": false,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 10
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "markLine": {
#                 "data": []
#             },
#             "seriesId": 5181155
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "",
#                 ""
#             ],
#             "selectedMode": "multiple",
#             "show": true,
#             "left": "center",
#             "top": "top",
#             "orient": "horizontal",
#             "textStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "animation": true,
#     "xAxis": [
#         {
#             "show": true,
#             "nameLocation": "middle",
#             "nameGap": 25,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "boundaryGap": true,
#             "type": "category",
#             "splitLine": {
#                 "show": false
#             },
#             "axisLine": {
#                 "lineStyle": {
#                     "width": 1
#                 }
#             },
#             "axisLabel": {
#                 "interval": 0,
#                 "rotate": 0,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 9
#                 }
#             },
#             "data": [
#                 2008.0,
#                 2009.0,
#                 2010.0,
#                 2011.0,
#                 2012.0,
#                 2013.0,
#                 2014.0,
#                 2015.0,
#                 2016.0,
#                 2017.0,
#                 2018.0,
#                 2019.0,
#                 2020.0,
#                 2021.0
#             ]
#         }
#     ],
#     "yAxis": [
#         {
#             "show": true,
#             "nameLocation": "middle",
#             "nameGap": 25,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "boundaryGap": true,
#             "type": "value",
#             "splitLine": {
#                 "show": true
#             },
#             "axisLine": {
#                 "lineStyle": {
#                     "width": 1
#                 }
#             },
#             "axisLabel": {
#                 "interval": "auto",
#                 "formatter": "{value} ",
#                 "rotate": 0,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 12
#                 }
#             }
#         }
#     ],
#     "color": []
# };
# myChart_480d7f8395cc4feeb7804781967ce448.setOption(option_480d7f8395cc4feeb7804781967ce448);
#
#     });
# </script>

# %%
release_type_cnt = data.pivot_table(index='release_year', columns='type', values='title', aggfunc='count').reset_index()

# %%
bar = Bar("",
         width=1200)
bar.use_theme("dark")
bar.add("", 
        release_type_cnt.release_year, 
        release_type_cnt.Movie,
        xaxis_label_textsize =9,
        xaxis_interval =0,
        label_text_size=10,
        is_stack=True,
        is_label_show=False, 
        is_datazoom_show=False)

bar.add("", 
        release_type_cnt.release_year, 
        release_type_cnt['TV Show'],
        xaxis_label_textsize =9,
        xaxis_interval =0,
        label_text_size=10,
        is_stack=True,
        is_label_show=False, 
        is_datazoom_show=False)
bar
# Out:
# <script>
#     require.config({
#         paths: {
#             'echarts': '/nbextensions/echarts/echarts.min'
#         }
#     });
# </script>
#     <div id="bee40b2c38d6425ab08155dcf96ee24c" style="width:1200px;height:400px;"></div>
#
#
# <script>
#     require(['echarts'], function(echarts) {
#
# var myChart_bee40b2c38d6425ab08155dcf96ee24c = echarts.init(document.getElementById('bee40b2c38d6425ab08155dcf96ee24c'), 'dark', {renderer: 'canvas'});
#
# var option_bee40b2c38d6425ab08155dcf96ee24c = {
#     "title": [
#         {
#             "left": "auto",
#             "top": "auto",
#             "textStyle": {
#                 "fontSize": 18
#             },
#             "subtextStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "toolbox": {
#         "show": true,
#         "orient": "vertical",
#         "left": "95%",
#         "top": "center",
#         "feature": {
#             "saveAsImage": {
#                 "show": true,
#                 "title": "save as image"
#             },
#             "restore": {
#                 "show": true,
#                 "title": "restore"
#             },
#             "dataView": {
#                 "show": true,
#                 "title": "data view"
#             }
#         }
#     },
#     "series_id": 7449262,
#     "tooltip": {
#         "trigger": "item",
#         "triggerOn": "mousemove|click",
#         "axisPointer": {
#             "type": "line"
#         },
#         "textStyle": {
#             "fontSize": 14
#         },
#         "backgroundColor": "rgba(50,50,50,0.7)",
#         "borderColor": "#333",
#         "borderWidth": 0
#     },
#     "series": [
#         {
#             "type": "bar",
#             "data": [
#                 NaN,
#                 2.0,
#                 3.0,
#                 3.0,
#                 3.0,
#                 1.0,
#                 1.0,
#                 2.0,
#                 3.0,
#                 2.0,
#                 3.0,
#                 1.0,
#                 4.0,
#                 1.0,
#                 3.0,
#                 1.0,
#                 2.0,
#                 2.0,
#                 1.0,
#                 4.0,
#                 3.0,
#                 2.0,
#                 2.0,
#                 5.0,
#                 4.0,
#                 10.0,
#                 6.0,
#                 7.0,
#                 9.0,
#                 6.0,
#                 7.0,
#                 10.0,
#                 11.0,
#                 12.0,
#                 17.0,
#                 11.0,
#                 12.0,
#                 9.0,
#                 11.0,
#                 8.0,
#                 16.0,
#                 15.0,
#                 19.0,
#                 16.0,
#                 20.0,
#                 24.0,
#                 20.0,
#                 23.0,
#                 21.0,
#                 34.0,
#                 32.0,
#                 32.0,
#                 33.0,
#                 40.0,
#                 44.0,
#                 51.0,
#                 55.0,
#                 67.0,
#                 82.0,
#                 74.0,
#                 113.0,
#                 118.0,
#                 154.0,
#                 145.0,
#                 173.0,
#                 225.0,
#                 264.0,
#                 398.0,
#                 658.0,
#                 767.0,
#                 767.0,
#                 633.0,
#                 517.0,
#                 277.0
#             ],
#             "stack": "stack_7449262",
#             "barCategoryGap": "20%",
#             "label": {
#                 "normal": {
#                     "show": false,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 10
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "markLine": {
#                 "data": []
#             },
#             "seriesId": 7449262
#         },
#         {
#             "type": "bar",
#             "data": [
#                 1.0,
#                 NaN,
#                 NaN,
#                 NaN,
#                 1.0,
#                 1.0,
#                 NaN,
#                 NaN,
#                 NaN,
#                 NaN,
#                 NaN,
#                 NaN,
#                 NaN,
#                 NaN,
#                 NaN,
#                 1.0,
#                 NaN,
#                 NaN,
#                 NaN,
#                 1.0,
#                 NaN,
#                 NaN,
#                 NaN,
#                 NaN,
#                 1.0,
#                 NaN,
#                 1.0,
#                 NaN,
#                 NaN,
#                 1.0,
#                 NaN,
#                 1.0,
#                 NaN,
#                 1.0,
#                 NaN,
#                 NaN,
#                 NaN,
#                 1.0,
#                 2.0,
#                 NaN,
#                 2.0,
#                 1.0,
#                 3.0,
#                 1.0,
#                 3.0,
#                 4.0,
#                 2.0,
#                 2.0,
#                 3.0,
#                 4.0,
#                 4.0,
#                 7.0,
#                 4.0,
#                 5.0,
#                 7.0,
#                 10.0,
#                 9.0,
#                 13.0,
#                 14.0,
#                 14.0,
#                 23.0,
#                 34.0,
#                 40.0,
#                 40.0,
#                 64.0,
#                 63.0,
#                 88.0,
#                 162.0,
#                 244.0,
#                 265.0,
#                 380.0,
#                 397.0,
#                 436.0,
#                 315.0
#             ],
#             "stack": "stack_7449262",
#             "barCategoryGap": "20%",
#             "label": {
#                 "normal": {
#                     "show": false,
#                     "position": "top",
#                     "textStyle": {
#                         "fontSize": 10
#                     }
#                 },
#                 "emphasis": {
#                     "show": true,
#                     "textStyle": {
#                         "fontSize": 12
#                     }
#                 }
#             },
#             "markPoint": {
#                 "data": []
#             },
#             "markLine": {
#                 "data": []
#             },
#             "seriesId": 7449262
#         }
#     ],
#     "legend": [
#         {
#             "data": [
#                 "",
#                 ""
#             ],
#             "selectedMode": "multiple",
#             "show": true,
#             "left": "center",
#             "top": "top",
#             "orient": "horizontal",
#             "textStyle": {
#                 "fontSize": 12
#             }
#         }
#     ],
#     "animation": true,
#     "xAxis": [
#         {
#             "show": true,
#             "nameLocation": "middle",
#             "nameGap": 25,
#             "nameTextStyle": {
#                 "fontSize": 14
#             },
#             "axisTick": {
#                 "alignWithLabel": false
#             },
#             "inverse": false,
#             "boundaryGap": true,
#             "type": "category",
#             "splitLine": {
#                 "show": false
#             },
#             "axisLine": {
#                 "lineStyle": {
#                     "width": 1
#                 }
#             },
#             "axisLabel": {
#                 "interval": 0,
#                 "rotate": 0,
#                 "margin": 8,
#                 "textStyle": {
#                     "fontSize": 9
#                 }
#             },
#             "data": [
#                 1925.0,
#                 1942.0,
#                 1943.0,
#                 1944.0,
#                 1945.0,
#                 1946.0,
#                 1947.0,
#                 1954.0,
#                 1955.0,
#                 1956.0,
#                 1958.0,
#                 1959.0,
#                 1960.0,
#                 1961.0,
#                 1962.0,
#                 1963.0,
#                 1964.0,
#                 1965.0,
#                 1966.0,
#                 1967.0,
#                 1968.0,
#                 1969.0,

# %%
release_type_cnt
# Out:
# type  release_year  Movie  TV Show
# 0             1925    NaN      1.0
# 1             1942    2.0      NaN
# 2             1943    3.0      NaN
# 3             1944    3.0      NaN
# 4             1945    3.0      1.0
# ..             ...    ...      ...
# 69            2017  767.0    265.0
# 70            2018  767.0    380.0
# 71            2019  633.0    397.0
# 72            2020  517.0    436.0
# 73            2021  277.0    315.0
#
# [74 rows x 3 columns]

# %%
#imdb dataset
# https://www.kaggle.com/stefanoleone992/imdb-extensive-dataset?select=IMDb+movies.csv

# %%
imdb_movies = pd.read_csv('IMDb movies.csv')

# %%
imdb_movies.columns
# Out:
# Index(['imdb_title_id', 'title', 'original_title', 'year', 'date_published',
#        'genre', 'duration', 'country', 'language', 'director', 'writer',
#        'production_company', 'actors', 'description', 'avg_vote', 'votes',
#        'budget', 'usa_gross_income', 'worlwide_gross_income', 'metascore',
#        'reviews_from_users', 'reviews_from_critics'],
#       dtype='object')

# %%
data.head(2)
# Out:
#   show_id     type                 title         director  \
# 0      s1    Movie  Dick Johnson Is Dead  Kirsten Johnson
# 1      s2  TV Show         Blood & Water              NaN
#
#                                                 cast        country  \
# 0                                                NaN  United States
# 1  Ama Qamata, Khosi Ngema, Gail Mabalane, Thaban...   South Africa
#
#            date_added  release_year rating   duration  \
# 0  September 25, 2021          2020  PG-13     90 min
# 1  September 24, 2021          2021  TV-MA  2 Seasons
#
#                                          listed_in  \
# 0                                    Documentaries
# 1  International TV Shows, TV Dramas, TV Mysteries
#
#                                          description date_added_year
# 0  As her father nears the end of his life, filmm...            2021
# 1  After crossing paths at a party, a Cape Town t...            2021

# %%
data_merged = pd.merge(data, imdb_movies, on='title', how='outer').sort_values(by='metascore', ascending=False)

# %%
data_merged[data_merged['show_id'].isnull()][:30]
# Out:
#       show_id type                         title director_x cast country_x  \
# 63089     NaN  NaN                       Boyhood        NaN  NaN       NaN
# 18133     NaN  NaN       La finestra sul cortile        NaN  NaN       NaN
# 30678     NaN  NaN             Fanny & Alexander        NaN  NaN       NaN
# 21547     NaN  NaN                 Il gattopardo        NaN  NaN       NaN
# 16874     NaN  NaN                Piombo rovente        NaN  NaN       NaN
# 38930     NaN  NaN       Tre colori - Film rosso        NaN  NaN       NaN
# 24563     NaN  NaN                Il conformista        NaN  NaN       NaN
# 25702     NaN  NaN                    Il padrino        NaN  NaN       NaN
# 15216     NaN  NaN  Notorious - L'amante perduta        NaN  NaN       NaN
# 21220     NaN  NaN             Lawrence d'Arabia        NaN  NaN       NaN
# 13676     NaN  NaN                 Quarto potere        NaN  NaN       NaN
# 19848     NaN  NaN  La donna che visse due volte        NaN  NaN       NaN
# 17859     NaN  NaN             Viaggio in Italia        NaN  NaN       NaN
# 9939      NaN  NaN                 Il mago di Oz        NaN  NaN       NaN
# 13993     NaN  NaN                    Casablanca        NaN  NaN       NaN
# 22657     NaN  NaN           Au hasard Balthazar        NaN  NaN       NaN
# 18478     NaN  NaN      La morte corre sul fiume        NaN  NaN       NaN
# 19828     NaN  NaN           L'infernale Quinlan        NaN  NaN       NaN
# 10663     NaN  NaN              Luci della città        NaN  NaN       NaN
# 13315     NaN  NaN                     Pinocchio        NaN  NaN       NaN
# 18133       $ 1000000       $ 36764313            $ 37032034     100.0
# 30678       $ 6000000        $ 6783304             $ 6795771     100.0
# 21547  ITL 2900000000              NaN              $ 269763     100.0
# 16874       $ 3400000              NaN                $ 7704     100.0
# 38930             NaN        $ 3581969             $ 3581969     100.0
# 24563        $ 750000          $ 58657              $ 400747     100.0
# 25702       $ 6000000      $ 134966411           $ 246120974     100.0
# 15216       $ 2000000              NaN              $ 113061     100.0
# 21220      $ 15000000       $ 45306425            $ 45710874     100.0
# 13676        $ 839727        $ 1585634             $ 1594107     100.0
# 19848       $ 2479000        $ 7705225             $ 7796389     100.0
# 17859             NaN              NaN                   NaN     100.0
# 9939        $ 2777000       $ 24790250            $ 26142032     100.0
# 13993        $ 950000        $ 4108411             $ 4374761     100.0
# 22657             NaN          $ 45406               $ 45406     100.0
# 18478        $ 795000              NaN                $ 2001      99.0
# 19828        $ 829000        $ 2247465             $ 2286947      99.0
# 10663       $ 1500000          $ 19181               $ 46008      99.0
# 13315       $ 2600000       $ 84254167           $ 121892045      99.0
# 17393       $ 2540800        $ 1826108             $ 1864182      99.0
# 9485         $ 385907              NaN                   NaN      99.0
# 24013             NaN         $ 771956              $ 840722      99.0
# 20180       $ 2883848              NaN            $ 83169282      98.0
# 16608        $ 250000          $ 46808               $ 46808      98.0
# 12602         $ 60000         $ 155895              $ 155895      98.0
# 16353       $ 1400000          $ 63463              $ 150438      98.0
# 20110       $ 3101000              NaN               $ 73446      98.0
# 18167   JPY 125000000         $ 318649              $ 322773      98.0
# 57610      $ 19000000       $ 37634615            $ 83850267      98.0
#
#        reviews_from_users reviews_from_critics
# 63089               998.0                580.0
# 18133               855.0                157.0
# 30678               143.0                101.0
# 21547               108.0                113.0
# 16874               155.0                131.0
# 38930               172.0                107.0
# 24563               111.0                128.0
# 25702              3977.0                253.0
# 15216               348.0                145.0
# 21220               676.0                146.0
# 13676              1452.0                248.0
# 19848               860.0                182.0
# 17859                38.0                 59.0
# 9939                688.0                168.0
# 13993              1303.0                196.0
# 22657                82.0                111.0
# 18478               453.0                211.0
# 19828               321.0                115.0
# 10663               295.0                122.0
# 13315               202.0                140.0
# 17393               671.0                155.0
# 9485                111.0                 77.0
# 24013                95.0                141.0
# 20180               422.0                224.0
# 16608               348.0                141.0
# 12602                46.0                 55.0
# 16353               373.0                140.0
# 20110               614.0                174.0
# 18167               715.0                130.0
# 57610              1278.0                457.0
#
# [30 rows x 34 columns]

# %%
data_merged[~data_merged['show_id'].isnull()][:30]
# Out:
#      show_id     type                                         title  \
# 8010   s7508    Movie                                     Moonlight
# 1195   s1127    Movie                                  My Fair Lady
# 9086   s8512    Movie                            The Social Network
# 6854   s6423    Movie                                         Carol
# 8311   s7803    Movie                                  Pulp Fiction
# 8481   s7958    Movie                              Schindler's List
# 3437   s3228    Movie                                  The Irishman
# 3067   s2882    Movie                                   Taxi Driver
# 2580   s2431    Movie                                     Lady Bird
# 4209   s3961    Movie                            The Burial of Kojo
# 8259   s7752    Movie                                       Platoon
# 2807   s2641  TV Show                                    After Life
# 7338   s6885    Movie                                  Gosford Park
# 2799   s2635    Movie                                    The Artist
# 7792  As the American Civil War continues to rage, A...      7.3   240462.0
# 7800  A new pair of best friends have their bond tes...      6.7     6749.0
# 1120  A Naval veteran arrives home from war unsettle...      7.2   150274.0
# 838   A determined woman works with a hardened boxin...      8.1   623282.0
# 5524  Two men return home from World War II to work ...      7.4    40622.0
# 7420  A defense officer, Nameless, was summoned by t...      7.9   172037.0
# 575   In a future where a failed climate-change expe...      7.1   307353.0
# 1002  The lives of three men who were childhood frie...      7.9   411389.0
#
#            budget usa_gross_income worlwide_gross_income metascore  \
# 8010    $ 4000000       $ 27854932            $ 65336603      99.0
# 1195   $ 17000000       $ 72560711            $ 72661442      95.0
# 9086   $ 40000000       $ 96962694           $ 224920315      95.0
# 6854   $ 11800000       $ 12711491            $ 40272135      94.0
# 8311    $ 8000000      $ 107928762           $ 222831817      94.0
# 8481   $ 22000000       $ 96898818           $ 322287794      94.0
# 3437  $ 159000000              NaN              $ 968853      94.0
# 3067    $ 1300000       $ 28262574            $ 28441292      94.0
# 2580   $ 10000000       $ 48958273            $ 79097104      94.0
# 4209          NaN              NaN                   NaN      93.0
# 8259    $ 6000000      $ 138530565           $ 138545632      92.0
# 2807          NaN         $ 801985              $ 801985      91.0
# 7338   $ 19800000       $ 41308615            $ 87754044      90.0
# 2799   $ 15000000       $ 44671682           $ 133432856      89.0
# 5792  BRL 2500000         $ 285930             $ 3085977      88.0
# 6750  $ 200000000      $ 700426566          $ 1347280838      88.0
# 7411   $ 12000000       $ 27007844            $ 37879877      88.0
# 8605   $ 12000000        $ 1830650             $ 1844789      87.0
# 3772          NaN         $ 233380             $ 2227905      87.0
# 3435          NaN              NaN                   NaN      87.0
# 4173          NaN              NaN               $ 25407      86.0
# 8406   $ 13000000       $ 14677654            $ 35401758      86.0
# 7792   $ 65000000      $ 182207973           $ 275293450      86.0
# 7800    $ 2000000         $ 702537             $ 2008649      86.0
# 1120   $ 32000000       $ 16377274            $ 28258060      86.0
# 838    $ 30000000      $ 100492203           $ 216763646      86.0
# 5524          NaN              NaN              $ 117344      85.0
# 7420   $ 31000000       $ 53710019           $ 177395557      85.0
# 575    $ 39200000        $ 4563650            $ 86758912      84.0
# 1002   $ 25000000       $ 90135191           $ 156595191      84.0
#
#       reviews_from_users reviews_from_critics
# 8010               920.0                517.0
# 1195               326.0                 94.0
# 9086               879.0                581.0
# 6854               340.0                456.0
# 8311              3058.0                289.0
# 8481              1845.0                232.0
# 3437              2705.0                438.0
# 3067              1178.0                289.0
# 2580               783.0                462.0
# 4209                10.0                  9.0
# 8259               607.0                138.0
# 2807               107.0                 93.0
# 7338               666.0                184.0
# 2799               664.0                585.0
# 5792                43.0                164.0
# 6750              3243.0                685.0
# 7411               446.0                320.0
# 8605               326.0                128.0
# 3772                64.0                136.0
# 3435                10.0                 13.0
# 4173               232.0                143.0
# 8406               677.0                479.0
# 7792               797.0                564.0
# 7800                45.0                131.0
# 1120               516.0                503.0
# 838               1230.0                266.0
# 5524               140.0                171.0
# 7420               867.0                150.0
# 575                920.0                490.0
# 1002              1041.0                236.0
#
# [30 rows x 34 columns]
